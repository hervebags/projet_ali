# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.close('all')

# %%
# %run main.py
# Out:
# Status of 'elasticsearch': yellow
# Got here!

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(nutrients_data_frame)
# Out:
#                                                     lipids_satures  \
# Bonbons, tablettes, chocolat au lait avec céréa...        8.739500
# Céréale, chaude, 9 grain, préparée, Rogers                0.079750
# Céréale, chaude, 9 grain, sèche, Rogers                   0.412500
# Céréale, chaude, Red River, préparée, Robin Hood          0.038500
# Céréale, chaude, Red River, séché, Robin Hood             0.220000
# Céréale, chaude, avoine (gruau), Rapide: Robin ...        0.913000
# Céréale, chaude, avoine (gruau), gros flocons, ...        0.158125
# Céréale, chaude, avoine (gruau), gros flocons, ...        0.130680
# Céréale, chaude, avoine (gruau), gros flocons, ...        0.735350
# Céréale, chaude, avoine (gruau), gros flocons, ...        0.678315
# Céréale, chaude, avoine (gruau), instantanée: B...        0.524260
# Céréale, chaude, avoine (gruau), instantanée: D...        0.357775
# Céréale, chaude, avoine (gruau), instantanée: D...        1.252900
# ...

# %%
nutrients_data_frame[0:3]
# Out:
#                                                     lipids_satures  \
# Bonbons, tablettes, chocolat au lait avec céréa...         8.73950
# Céréale, chaude, 9 grain, préparée, Rogers                 0.07975
# Céréale, chaude, 9 grain, sèche, Rogers                    0.41250
#
#                                                     lipides_trans    calcium  \
# Bonbons, tablettes, chocolat au lait avec céréa...            0.0  102.85000
# Céréale, chaude, 9 grain, préparée, Rogers                    0.0    7.22645
# Céréale, chaude, 9 grain, sèche, Rogers                       0.0   30.25000
#
#                                                     cholesterol      fer  \
# Bonbons, tablettes, chocolat au lait avec céréa...        12.65  1.45750
# Céréale, chaude, 9 grain, préparée, Rogers                 0.00  0.53185
# Céréale, chaude, 9 grain, sèche, Rogers                    0.00  2.88750
#
#                                                      fibres   glucides  \
# ...

# %%
nutrients_data_frame.loc[:, ['Sugar score', 'Global score', 'Recommendation']]
# Out:
#                                                     Sugar score  Global score  \
# Bonbons, tablettes, chocolat au lait avec céréa...     0.000000      0.240750
# Céréale, chaude, 9 grain, préparée, Rogers             0.000000      0.243253
# Céréale, chaude, 9 grain, sèche, Rogers                0.000000      0.500000
# Céréale, chaude, Red River, préparée, Robin Hood       0.000000      0.211325
# Céréale, chaude, Red River, séché, Robin Hood          0.000000      0.480000
# ...                                                         ...           ...
# Céréale, prête-à-manger, son de blé 100%, Post         0.640429      0.820215
# Céréale, prête-à-manger, son de maïs carrées, Q...     0.767050      0.883525
# Céréale-prête-à-manger, Victoire, Choix du prés...     0.718650      0.686700
# Substitut de repas (céréale), prête-à-manger, V...     0.753850      0.709800
# Substitut de repas (céréale, prête-à-manger, Fo...     0.816275      0.752837
#
# ...

# %%
nutrients_data_frame.mean()
# Out:
# lipids_satures      0.623658
# lipides_trans       0.001452
# calcium            42.629310
# cholesterol         0.106585
# fer                 4.266881
# fibres              4.609572
# glucides           37.300363
# lipides             2.733813
# potassium         149.474643
# proteines           4.793281
# sodium            167.712383
# sucres              9.210386
# vitamine_c          0.192115
# vitamine_a          3.325768
# Fiber score         0.699433
# Sugar score         0.738620
# Global score        0.719026
# dtype: float64

# %%
nutrients_data_frame.sort_values(by='Global score', ascending=False)[0:10]
# Out:
#                                                     lipids_satures  \
# Céréale, prête-à-manger, Fibre 1, General Mills            0.26235
# Céréale, chaude, avoine (gruau), son de blé, so...         0.62865
# Céréale, prête-à-manger, bouchées de blé filalm...         0.23705
# Céréale, prête-à-manger, bouchées blé filamenté...         0.21285
# Céréale, prête-à-manger, blé filamenté, Post               0.28655
# Céréale, prête-à-manger, Fiber 1: grappes au mi...         0.28545
# Céréale, prête-à-manger, 'All Bran' bran flakes...         0.26070
# Céréale, prête-à-manger, Muffets: blé filamenté...         0.22275
# Céréale, prête-à-manger, Multigrain, Nature's Path         0.36300
# Céréale, prête-à-manger, blé soufflé, Quaker               0.27445
#
#                                                     lipides_trans     calcium  \
# Céréale, prête-à-manger, Fibre 1, General Mills               0.0  217.800000
# ...

# %%
nutrients_data_frame.loc[:, ['Global score']].sort_values(by='Global score', ascending=False).iloc[0:300].plot()
plt.xticks(rotation=90)
# Out:
# (array([-50.,   0.,  50., 100., 150., 200., 250.]),
#  <a list of 7 Text xticklabel objects>)

# %%
nutrients_data_frame.loc[:, ['Global score']].sort_values(by='Global score', ascending=False).iloc[0:20].plot.bar()

# %%
print("Fin!")
# Out:
# Fin!
